# %%
from qiskit import QuantumCircuit

# %%
def diffuser(qc,n):
    qc.h(range(n))
    qc.x(range(n))
    qc.h(n-1)
    qc.mcx(list(range(n-1)),n-1)
    qc.h(n-1)
    qc.x(range(n))
    qc.h(range(n))

# %%
n=3
qc= QuantumCircuit(n)
diffuser(qc,n)
qc.draw('mpl')
